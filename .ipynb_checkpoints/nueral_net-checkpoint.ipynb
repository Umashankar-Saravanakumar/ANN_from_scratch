# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation

# %%
np.random.seed(42)

# %%
import pandas as pd
df = pd.read_csv("scatter-points.csv")
points = df.to_numpy()

# %%
blue_points = points[points[:,0] < 0.4]
blue_points = blue_points[blue_points[:,1] > 0.6]
blue_points
# Out:
# array([[ 1.43922558e-02,  6.20535117e-01],
#        [ 4.90688096e-02,  7.32256330e-01],
#        [-4.45382762e-04,  7.83587757e-01],
#        [ 7.76752547e-02,  9.16243939e-01],
#        [ 5.80344384e-02,  1.05952167e+00],
#        [ 1.63829004e-01,  6.07564921e-01],
#        [ 1.09105153e-01,  7.33172229e-01],
#        [ 1.36793376e-01,  7.93097221e-01],
#        [ 1.79665223e-01,  9.44787091e-01],
#        [ 1.12911634e-01,  1.00272322e+00],
#        [ 2.26428058e-01,  7.06803101e-01],
#        [ 2.32980825e-01,  8.45286617e-01],
#        [ 2.43314650e-01,  9.34099742e-01],
#        [ 2.94359486e-01,  1.00382860e+00],
#        [ 3.52370219e-01,  7.37352359e-01],
#        [ 3.44153908e-01,  7.76336596e-01],
#        [ 3.56722150e-01,  9.55610465e-01],
#        [ 3.92371480e-01,  1.04864216e+00]])

# %%
plt.scatter(blue_points[:,0], blue_points[:,1], color='blue')
plt.xlim(-0.15, 1.15)
plt.ylim(-0.05, 1.15)
# Out:
# (-0.05, 1.15)

# %%
mask = ~np.isin(points, blue_points).all(axis=1)
red_points = points[mask]
red_points
# Out:
# array([[ 0.04531427,  0.06796733],
#        [ 0.06473172,  0.13577409],
#        [ 0.00769037,  0.27796893],
#        [ 0.03913065,  0.38939614],
#        [ 0.0430464 ,  0.4502481 ],
#        [ 0.12159864,  0.01036217],
#        [ 0.19107559,  0.11410066],
#        [ 0.15812699,  0.25332874],
#        [ 0.17941997,  0.39894367],
#        [ 0.16713303,  0.50791574],
#        [ 0.23097108, -0.00352038],
#        [ 0.22853833,  0.17433221],
#        [ 0.27433542,  0.21984868],
#        [ 0.28456946,  0.37403235],
#        [ 0.24259039,  0.44859529],
#        [ 0.29524062,  0.56965505],
#        [ 0.40919619, -0.0014033 ],
#        [ 0.37718229,  0.18521288],
#        [ 0.34790792,  0.21981189],
#        [ 0.37376182,  0.40862986],
#        [ 0.38837815,  0.5157359 ],
#        [ 0.33170812,  0.5919116 ],
#        [ 0.50838969,  0.0142784 ],
#        [ 0.52381411,  0.161414  ],
#        [ 0.51552159,  0.26575455],
#        [ 0.44176378,  0.41141589],
#        [ 0.47269994,  0.47700368],
#        [ 0.47659295,  0.56198696],
#        [ 0.50193796,  0.66940252],
#        [ 0.46143055,  0.85445513],
#        [ 0.4749202 ,  0.90094037],
#        [ 0.4412969 ,  1.01932283],
#        [ 0.59926743,  0.01040915],
#        [ 0.58365327,  0.18285348],
#        [ 0.60194742,  0.23328917],
#        [ 0.57692065,  0.3500451 ],
#        [ 0.57685496,  0.45228842],
#        [ 0.58958308,  0.55942048],
#        [ 0.5627581 ,  0.69954496],
#        [ 0.60116992,  0.7923347 ],
#        [ 0.56321714,  0.92765483],
#        [ 0.55875566,  1.01208352],
#        [ 0.67044707,  0.05916994],
#        [ 0.69568155,  0.16773795],
#        [ 0.68811659,  0.24058215],
#        [ 0.72793223,  0.37026736],
#        [ 0.74523807,  0.50000306],
#        [ 0.7284483 ,  0.57915042],
#        [ 0.70165014,  0.71850525],
#        [ 0.73971417,  0.8439717 ],
#        [ 0.66990116,  0.95007203],
#        [ 0.68096266,  1.01254882],
#        [ 0.84518714,  0.02593588],
#        [ 0.77887781,  0.11233136],
#        [ 0.79417145,  0.21848118],
#        [ 0.8478654 ,  0.39436561],
#        [ 0.80509405,  0.43982512],
#        [ 0.8347863 ,  0.60194651],
#        [ 0.82040151,  0.70288175],
#        [ 0.83211867,  0.85703549],
#        [ 0.80860512,  0.93121836],
#        [ 0.80224725,  1.02239466],
#        [ 0.94047859,  0.06844313],
#        [ 0.93559209,  0.14779052],
#        [ 0.95247389,  0.26695318],
#        [ 0.92888223,  0.39193225],
#        [ 0.89112466,  0.44281481],
#        [ 0.93045356,  0.56522153],
#        [ 0.93725995,  0.72030476],
#        [ 0.96801721,  0.84017968],
#        [ 0.96866318,  0.94517185],
#        [ 0.9372708 ,  1.07172197],
#        [ 1.07296329,  0.02371587],
#        [ 1.03259263,  0.12694327],
#        [ 1.03441788,  0.24416794],
#        [ 1.01927266,  0.37636441],
#        [ 1.0677625 ,  0.44385426],
#        [ 1.01980014,  0.55969874],
#        [ 1.0778981 ,  0.73872181],
#        [ 1.03195084,  0.78315531],
#        [ 1.06949114,  0.90877277],
#        [ 1.01035586,  1.02190629]])

# %%
plt.scatter(red_points[:,0], red_points[:,1], color='red')
plt.xlim(-0.15, 1.15)
plt.ylim(-0.05, 1.15)
# Out:
# (-0.05, 1.15)

# %%
plt.scatter(blue_points[:,0], blue_points[:,1], color='blue')
plt.scatter(red_points[:,0], red_points[:,1], color='red')

# %%
# Combine points and create binary labels
X = np.concatenate((red_points, blue_points), axis=0)
# Red = 0, Blue = 1 (Binary Classification)
Y_red = np.zeros((len(red_points), 1))
Y_blue = np.ones((len(blue_points), 1))
Y = np.concatenate((Y_red, Y_blue), axis=0)

# %%
# Shuffle data for better SGD training
indices = np.arange(len(X))
np.random.shuffle(indices)
X_shuffled = X[indices]
Y_shuffled = Y[indices].flatten() # Flatten Y to be a vector of scalars for single output

# %%
# --- 2. Test-Train Split ---
# Total number of samples: 106
total_samples = len(X_shuffled)
# Use 80% for training
train_size = int(0.8 * total_samples) 

# Split the data
X_train, X_test = X_shuffled[:train_size], X_shuffled[train_size:]
Y_train, Y_test = Y_shuffled[:train_size], Y_shuffled[train_size:]

print(f"Total Samples: {total_samples}")
print(f"Training Samples: {len(X_train)}")
print(f"Testing Samples: {len(X_test)}")
# Out:
# Total Samples: 100
# Training Samples: 80
# Testing Samples: 20

# %%
def sigmoid(z):
    """Sigmoid activation function."""
    return 1.0 / (1.0 + np.exp(-z))

def d_sigmoid(a):
    """Derivative of the sigmoid function, where a = sigmoid(z)."""
    return a * (1.0 - a)

def tanh(z):
    """Hyperbolic tangent activation function."""
    return np.tanh(z)

def d_tanh(a):
    """Derivative of the tanh function, where a = tanh(z)."""
    return 1.0 - a**2

# %%
class NeuralNetwork:
    def __init__(self, layer_dims):
        self.layer_dims = layer_dims
        self.num_layers = len(layer_dims) - 1
        # Initialize weights using He initialization variation
        self.weights = [
            np.random.randn(layer_dims[i], layer_dims[i+1]) * np.sqrt(2.0/layer_dims[i])
            for i in range(self.num_layers)
        ]
        # Biases initialized to zero
        self.biases = [np.zeros(layer_dims[i+1]) for i in range(self.num_layers)]

    def forward(self, x):
        # Input 'x' is a single sample (vector)
        a = x
        self.zs = []
        self.activations = [a]
        
        for i in range(self.num_layers):
            z = np.dot(a, self.weights[i]) + self.biases[i]
            self.zs.append(z)
            
            if i == self.num_layers - 1:
                # Output layer uses Sigmoid
                a = sigmoid(z)
            else:
                # Hidden layers use Tanh
                a = tanh(z)
            self.activations.append(a)
            
        return a

    def compute_loss(self, y_true, y_pred):
        # Binary Cross-Entropy Loss for a single sample
        y_pred = np.clip(y_pred, 1e-8, 1 - 1e-8)
        return -np.mean(y_true * np.log(y_pred) + (1-y_true) * np.log(1-y_pred))

    def backward(self, x, y_true, learning_rate=0.01):
        # x and y_true are single samples (vectors/scalars)
        y_pred = self.activations[-1]
        
        # Initial Delta: dL/dz_L = y_pred - y_true (BCE + Sigmoid simplification)
        delta = y_pred - y_true 
        
        grads_w = [None] * self.num_layers
        grads_b = [None] * self.num_layers
        
        # Backpropagate Error
        for l in reversed(range(self.num_layers)):
            # dw_l = activation_{l} * delta_l
            grads_w[l] = np.outer(self.activations[l], delta)
            
            # db_l = delta_l
            grads_b[l] = delta 
            
            # Update delta for the next layer (l-1)
            if l > 0:
                # delta_{l-1} = (W_l^T @ delta_l) * d_activation(a_{l-1})
                # self.activations[l] is a_{l-1} when looking at weights W_l
                delta = np.dot(self.weights[l], delta) * d_tanh(self.activations[l])

        # Update Weights and Biases (Stochastic Gradient Descent)
        for l in range(self.num_layers):
            self.weights[l] -= learning_rate * grads_w[l]
            self.biases[l] -= learning_rate * grads_b[l]
            
        return y_pred

    def fit(self, X, Y, epochs=500, learning_rate=0.01):
        loss_history = []
        for epoch in range(epochs):
            total_loss = 0
            for x, y_true in zip(X, Y):
                self.forward(x)
                self.backward(x, y_true, learning_rate)
                loss = self.compute_loss(y_true, self.activations[-1])
                total_loss += loss
            avg_loss = total_loss / len(X)
            loss_history.append(avg_loss)
            print(f"Epoch {epoch+1}/{epochs} Loss: {avg_loss:.4f}")  # Every epoch, for precise feedback
            yield self.weights, self.biases   # <--- Every epoch, for smooth animation

# %%
layer_dims = [2, 3, 3, 1]
nn = NeuralNetwork(layer_dims)

# %%
nn.layer_dims
# Out:
# [2, 3, 3, 1]

# %%
predictions = []

def predict(nn, X):
    """Generates binary predictions (0 or 1) for a set of samples."""
    for x in X:
        # Use forward pass and threshold the output (0.5)
        output = nn.forward(x)[0] 
        predictions.append(output)
    return np.array(predictions)

Y_pred_test = predict(nn, X_test)
Y_true_test = Y_test

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(blue_points[:,0], blue_points[:,1], color='blue', label='Class 1')
ax.scatter(red_points[:,0], red_points[:,1], color='red', label='Class 0')
ax.set_xlim(-0.1, 1.15)
ax.set_ylim(-0.1, 1.15)
ax.set_xlabel("x1")
ax.set_ylabel("x2")
# Out:
# Text(0, 0.5, 'x2')

# %%
lines = [ax.plot([], [], label=f'Neuron {i+1}')[0] for i in range(layer_dims[1])]

x_vals = np.linspace(0, 1.2, 200)

def update(params):
    weights, biases = params
    w = weights[0]   # First layer weights shape (2,3)
    b = biases[0]    # First layer biases shape (3,)
    for i, line in enumerate(lines):
        w1, w2 = w[:, i]
        bias = b[i]
        # Avoid divide by zero (vertical line)
        if abs(w2) < 1e-8:
            y_plot = np.full_like(x_vals, -bias)
        else:
            m = -w1 / w2
            c = -bias / w2
            y_plot = m * x_vals + c
        line.set_data(x_vals, y_plot)
    return lines

ani = animation.FuncAnimation(
    fig, update,
    frames=nn.fit(X_shuffled, Y_shuffled, epochs=500, learning_rate=0.01),
    interval=40, blit=True, repeat=False, cache_frame_data=False
)

plt.show()
# Out:
# Epoch 1/500 Loss: 0.5803
# Epoch 2/500 Loss: 0.5172
